# %%
import csv
import json
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint
import numpy as np

#Getting geo_code for each province (with census sub-division -CSD- per province)



code_dict={"00":"All provinces and territories",
            "10" : "Newfoundland and Labrador",
            "11" : "Prince Edward Island",
            "12" : "Nova Scotia",
            "13" : "New Brunswick",
            "24" : "Quebec",
            "35" : "Ontario",
            "46" : "Manitoba",
            "47" : "Saskatchewan",
            "48" : "Alberta",
            "59" : "British Columbia",
            "60" : "Yukon",
            "61" : "Northwest Territories",
            "62" : "Nunavut"}


for key,value in code_dict.items():
    province_code=key
    url_geocode="https://www12.statcan.gc.ca/rest/census-recensement/CR2016Geo.json?lang=E&geos=CSD&cpt=35"
    previous_response = requests.get(url_geocode+province_code)
    response = json.loads(previous_response.text[2:])
    str("indian_reserve_"+value)={}
    for i in np.arange(len(response["DATA"])):
        if response["DATA"][i][5]=="Indian reserve":
            str("indian_reserve_"+value)[response["DATA"][i][0]]=response["DATA"][i][4]

            
url_geocode="https://www12.statcan.gc.ca/rest/census-recensement/CR2016Geo.json?lang=E&geos=CSD&cpt=35"
previous_response = requests.get(url_geocode)
        #previous_response = requests.get(url_geocode+province_code)
response = json.loads(previous_response.text[2:])
for i in np.arange(len(response["DATA"])):
    if response["DATA"][i][5]=="Indian reserve":
        indian_reserve[response["DATA"][i][0]]=response["DATA"][i][4]
pprint(indian_reserve)
print(indian_reserve)

#url= "https://www12.statcan.gc.ca/rest/census-recensement/CPR2016.json?lang=E&notes=0&dguid=2016A00053501007&topic=7"

#response = requests.get('https://www12.statcan.gc.ca/rest/census-recensement/CPR2016.json?lang=E&notes=0&topic=1')
#print(response.text)
#b = json.loads(response.text[2:])
#pprint(b['DATA'])
# Out:
#   File "<ipython-input-3-4369a972c54e>", line 30
#     for i in np.arange(len(response["DATA"])):
#     ^
# IndentationError: unexpected indent

# %%
import csv
import json
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint
import numpy as np
previous_response = requests.get('https://www12.statcan.gc.ca/rest/census-recensement/CR2016Geo.json?lang=E&geos=CSD&cpt=35')
response = json.loads(previous_response.text[2:])
print(response["DATA"])
# Out:
# [['2016A00053501005', '35', 'Ontario', '3501005', 'South Glengarry', 'Township', 3.9, 2.7, '00000'], ['2016A00053501007', '35', 'Ontario', '3501007', 'Akwesasne (Part) 59', 'Indian reserve', 34.1, 22.4, '03323'], ['2016A00053501011', '35', 'Ontario', '3501011', 'South Stormont', 'Township', 3.2, 5.9, '00000'], ['2016A00053501012', '35', 'Ontario', '3501012', 'Cornwall', 'City', 4.2, 4.0, '00000'], ['2016A00053501020', '35', 'Ontario', '3501020', 'South Dundas', 'Municipality', 4.3, 7.0, '00000'], ['2016A00053501030', '35', 'Ontario', '3501030', 'North Dundas', 'Township', 4.5, 7.2, '00000'], ['2016A00053501042', '35', 'Ontario', '3501042', 'North Stormont', 'Township', 4.4, 5.4, '00000'], ['2016A00053501050', '35', 'Ontario', '3501050', 'North Glengarry', 'Township', 4.4, 7.5, '00000'], ['2016A00053502001', '35', 'Ontario', '3502001', 'East Hawkesbury', 'Township', 3.8, 9.7, '00000'], ['2016A00053502008', '35', 'Ontario', '3502008', 'Hawkesbury', 'Town', 4.8, 6.3, '00000'], ['2016A00
# ...

# %%
import csv
import json
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint
import numpy as np
indian_reserve={}

#Ontario_code=35
url_geocode="https://www12.statcan.gc.ca/rest/census-recensement/CR2016Geo.json?lang=E&geos=CSD&cpt=35"
previous_response = requests.get(url_geocode)
response = json.loads(previous_response.text[2:])
for i in np.arange(len(response["DATA"])):
    if response["DATA"][i][5]=="Indian reserve":
        indian_reserve[response["DATA"][i][0]]=response["DATA"][i][4]
pprint(indian_reserve)
# Out:
# {'2016A00053501007': 'Akwesasne (Part) 59',
#  '2016A00053512004': 'Tyendinaga Mohawk Territory',
#  '2016A00053514027': 'Alderville First Nation',
#  '2016A00053515008': 'Hiawatha First Nation',
#  '2016A00053515019': 'Curve Lake First Nation 35',
#  '2016A00053518022': 'Mississaugas of Scugog Island',
#  '2016A00053519076': 'Chippewas of Georgina Island First Nation',
#  '2016A00053528035': 'New Credit (Part) 40A',
#  '2016A00053528037': 'Six Nations (Part) 40',
#  '2016A00053529020': 'Six Nations (Part) 40',
#  '2016A00053529021': 'New Credit (Part) 40A',
#  '2016A00053536029': 'Moravian 47',
#  '2016A00053538004': 'Walpole Island 46',
#  '2016A00053538025': 'Sarnia 45',
#  '2016A00053538056': 'Kettle Point 44',
#  '2016A00053539017': 'Chippewas of the Thames First Nation 42',
#  '2016A00053539018': 'Munsee-Delaware Nation 1',
#  '2016A00053539021': 'Oneida 41',
#  '2016A00053541056': "Chief's Point No. 28",
#  '2016A00053541057': 'Saugeen 29',
# ...

# %%
len(indian_reserve)
# Out:
# 140

# %%
import csv
import json
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint
import numpy as np

#Getting geo_code for each province (with census sub-division -CSD- per province)



code_dict={"00":"All provinces and territories",
            "10" : "Newfoundland and Labrador",
            "11" : "Prince Edward Island",
            "12" : "Nova Scotia",
            "13" : "New Brunswick",
            "24" : "Quebec",
            "35" : "Ontario",
            "46" : "Manitoba",
            "47" : "Saskatchewan",
            "48" : "Alberta",
            "59" : "British Columbia",
            "60" : "Yukon",
            "61" : "Northwest Territories",
            "62" : "Nunavut"}


for key,value in code_dict.items():
    province_code=key
    url_geocode="https://www12.statcan.gc.ca/rest/census-recensement/CR2016Geo.json?lang=E&geos=CSD&cpt="
    previous_response = requests.get(url_geocode+province_code)
    response = json.loads(previous_response.text[2:])
    dictionary=
    "indian_reserve_"+value={}
    for i in np.arange(len(response["DATA"])):
        if response["DATA"][i][5]=="Indian reserve":
            str("indian_reserve_"+value)[response["DATA"][i][0]]=response["DATA"][i][4]
# Out:
#   File "<ipython-input-5-bca3acb260af>", line 34
#     "indian_reserve_"+value={}
#     ^
# SyntaxError: can't assign to operator

# %%
code_dict={"00":"All provinces and territories",
            "10" : "Newfoundland and Labrador",
            "11" : "Prince Edward Island",
            "12" : "Nova Scotia",
            "13" : "New Brunswick",
            "24" : "Quebec",
            "35" : "Ontario",
            "46" : "Manitoba",
            "47" : "Saskatchewan",
            "48" : "Alberta",
            "59" : "British Columbia",
            "60" : "Yukon",
            "61" : "Northwest Territories",
            "62" : "Nunavut"}

code_dict=code_dict2

print(code_dict2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-53f9462a66f5> in <module>()
#      14             "62" : "Nunavut"}
#      15
# ---> 16 code_dict=code_dict2.dict
#      17
#      18 print(code_dict2)
#
# NameError: name 'code_dict2' is not defined

# %%
import csv
import json
import matplotlib.pyplot as plt
import requests
import pandas as pd
from pprint import pprint
import numpy as np

url_geocode="https://www12.statcan.gc.ca/rest/census-recensement/CPR2016.json?lang=E&notes=0&dguid=2016A00053501007&topic=1"
previous_response = requests.get(url_geocode)
response = json.loads(previous_response.text[2:])
list1=[]
for i in np.arange(len(response["DATA"])):
    list1.append(response["DATA"][i][10])
pprint(response)
# Out:
# {'COLUMNS': ['PROV_TERR_ID',
#              'PROV_TERR_NAME_NOM',
#              'GEO_UID',
#              'GEO_ID',
#              'GEO_NAME_NOM',
#              'GEO_TYPE',
#              'TOPIC_THEME',
#              'TEXT_ID',
#              'HIER_ID',
#              'INDENT_ID',
#              'TEXT_NAME_NOM',
#              'NOTE_ID',
#              'NOTE',
#              'T_DATA_DONNEE',
#              'T_SYM',
#              'M_DATA_DONNEE',
#              'M_SYM',
#              'F_DATA_DONNEE',
#              'F_SYM'],
#  'DATA': [['35',
#            'Ontario',
#            '2016A00053501007',
#            '3501007',
#            'Akwesasne (Part) 59',
#            'Indian reserve',
#            'Aboriginal peoples',
#            24000,
#            '6.1.1',
#            0,
#            'Total - Aboriginal identity for the population in private '
#            'households - 25% sample data',
#            79,
#            None,
#            1420.0,
#            None,
# ...

# %%
url_geocode2="https://www12.statcan.gc.ca/rest/census-recensement/CPR2016.json?lang=E&notes=0&dguid=2016A00053501007&topic=13"
previous_response2 = requests.get(url_geocode2)
response2 = json.loads(previous_response.text[2:])
list2=[]
for i in np.arange(len(response2["DATA"])):
    list2.append(response2["DATA"][i][10])
pprint(list2)
# Out:
# ['Total - Aboriginal identity for the population in private households - 25% '
#  'sample data',
#  '  Aboriginal identity',
#  '    Single Aboriginal responses',
#  '      First Nations (North American Indian)',
#  '      Métis',
#  '      Inuk (Inuit)',
#  '    Multiple Aboriginal responses',
#  '    Aboriginal responses not included elsewhere',
#  '  Non-Aboriginal identity',
#  'Total - Population by Registered or Treaty Indian status for the population '
#  'in private households - 25% sample data',
#  '  Registered or Treaty Indian',
#  '  Not a Registered or Treaty Indian',
#  'Total - Aboriginal ancestry for the population in private households - 25% '
#  'sample data',
#  '  Aboriginal ancestry (only)',
#  '    Single Aboriginal ancestry (only)',
#  '      First Nations (North American Indian) single ancestry',
#  '      Métis single ancestry',
#  '      Inuit single ancestry',
#  '    Multiple Aboriginal ancestries (only)',
# ...
