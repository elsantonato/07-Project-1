# %%
import pandas as pd
import matplotlib.pyplot as plt

% matplotlib inline

#membership_file = "../API/Resources/98-400-X2016393_ENG_CSV/98-400-X2016393_English_CSV_data.csv"

# %%
#membership_df = pd.read_csv(membership_file)

# %%
#membership_df.head()

# %%
#membership_df.tail()

# %%
#membership_df.columns

# %%
#membership_df.info()

# %%
#highlights_CANPR_df = pd.read_csv('Resources/98-402-X2016009-T1-CSV-Eng/98-402-X2016009-T1-CANPR-Eng.CSV')

#highlights_CMACA_df = pd.read_csv('Resources/98-402-X2016009-T1-CSV-Eng/98-402-X2016009-T1-CMACA-Eng.CSV', encoding='utf_8')

# %%
#highlights_CSD_df = pd.read_csv('../API/Resources/98-402-X2016009-T1-CSV-Eng/98-402-X2016009-T1-CSD-Eng.csv')
#highlights_CSD_df.head()
#highlights_CSD_df.columns

# %%
#highlights_CSD_df.info()

# %%
health_df = pd.read_csv('../API/Resources/13100458-eng/13100458.csv')
#health_df.head()
health_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Sex', 'Aboriginal identity', 'Indicators',
#        'Characteristics', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID',
#        'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED',
#        'DECIMALS'],
#       dtype='object')

# %%
health_df.head()
# Out:
#     REF_DATE     GEO  DGUID         Sex Aboriginal identity Indicators  \
# 0  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 1  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 2  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 3  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 4  2007/2010  Canada    NaN  Both sexes    Total population     Asthma
#
#                                      Characteristics   UOM  UOM_ID  \
# 0                              Age-standardized rate  Rate     257
# 1  Low 95% confidence interval, age-standardized ...  Rate     257
# 2  High 95% confidence interval, age-standardized...  Rate     257
# 3  Coefficient of variation for age-standardized ...  Rate     257
# 4                              Age-standardized rate  Rate     257
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE STATUS  SYMBOL  \
# ...

# %%
# Create a new table that takes the Aboriginal Identity data and all the columns relating to geo and health
health_indicators_table = health_df[["REF_DATE", "GEO", "Sex", 
                                     "Aboriginal identity", "Indicators", "Characteristics", "VALUE"]]

# %%
health_indicators_table.head()

# Create a pivot table to isolate health indicators between First Nations, Inuit, Métis, and Non-Aboriginal identities
First_Nations_df = health_indicators_table.loc[health_indicators_table["Characteristics"] == 'Age-standardized rate']
pivoted_df = First_Nations_df.pivot_table(index=["REF_DATE",  "GEO", "Sex","Indicators"], columns="Aboriginal identity", values="VALUE").reset_index()
pivoted_df.head()
# Out:
# Aboriginal identity   REF_DATE      GEO         Sex  \
# 0                    2007/2010  Alberta  Both sexes
# 1                    2007/2010  Alberta  Both sexes
# 2                    2007/2010  Alberta  Both sexes
# 3                    2007/2010  Alberta  Both sexes
# 4                    2007/2010  Alberta  Both sexes
#
# Aboriginal identity                                         Indicators  \
# 0                    5 or more drinks on one occasion, at least onc...
# 1                                                            Arthritis
# 2                                                               Asthma
# 3                    Body mass index, self-reported, adult (18 year...
# 4                    Body mass index, self-reported, adult (18 year...
#
# Aboriginal identity  First Nations  Inuit  Métis  \
# 0                             32.1    NaN   31.9
# 1                             10.8    NaN   10.8
# 2                             15.7    NaN   11.1
# ...

# %%
health_indicators_table["Aboriginal identity"].unique()
# Out:
# array(['Total population', 'First Nations', 'Métis', 'Inuit',
#        'Non-Aboriginal identity population'], dtype=object)

# %%
health_indicators_table["GEO"].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador', 'Prince Edward Island',
#        'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba',
#        'Saskatchewan', 'Alberta', 'British Columbia', 'Yukon',
#        'Northwest Territories', 'Nunavut'], dtype=object)

# %%
# Collect only data related to Aboriginal identity, First Nations
#First_Nations_df = health_indicators_table.loc[health_indicators_table["Aboriginal identity"] == 'First Nations']
#First_Nations_df.head()

# Isolate data related to age-standardized rate
#First_Nations_df = First_Nations_df.loc[First_Nations_df["Characteristics"] == 'Age-standardized rate']
#First_Nations_df.head()

# Pivot table to switch index coordinates 
#First_Nations_df.pivot_table(index=["REF_DATE",  "GEO", "Sex","Indicators"], columns="Aboriginal identity", values="VALUE").reset_index()

# %%
# Collect only data related to Aboriginal identity, Métis
#Métis_df = health_indicators_table.loc[health_indicators_table["Aboriginal identity"] == 'Métis']
#Métis_df.head()

# Isolate data related to age-standardized rate
#Métis_df = Métis_df.loc[Métis_df["Characteristics"] == 'Age-standardized rate']
#Métis_df.head()

# %%
# Collect only data related to Aboriginal identity, Inuit
#Inuit_df = health_indicators_table.loc[health_indicators_table["Aboriginal identity"] == 'Inuit']
#Inuit_df.head()

# Isolate data related to age-standardized rate
#Inuit_df = Inuit_df.loc[Inuit_df["Characteristics"] == 'Age-standardized rate']
#Inuit_df.head()

# %%
#merged_identity_df = pd.merge(First_Nations_df, Métis_df, Inuit_df, on='Aboriginal Identity', how='left')

# %%
# Collect only data related to Non-Aboriginal identity
#non_aboriginal_identity = health_indicators_table.loc[health_indicators_table["Aboriginal Identity"] == 'Non-Aboriginal identity population']
#non_aboriginal_identity.head()

# %%
#health_indicators_table["Indicators"].unique()

# %%
#'Has a regular medical doctor'
#has_doctor = health_indicators_table[health_indicators_table["Indicators"] == "Has a regular medical doctor"]
#has_doctor

# %%
health_indicators_table["Characteristics"].unique()
# Out:
# array(['Age-standardized rate',
#        'Low 95% confidence interval, age-standardized rate',
#        'High 95% confidence interval, age-standardized rate',
#        'Coefficient of variation for age-standardized rate'], dtype=object)

# %%
#crime_df = pd.read_csv('Resources/35100177-eng/35100177.csv')
#crime_df.head()

# %%
#crime_df.columns

# %%
# We only want -- data, so create a new table that takes the -- and all the columns relating to --
#crime_indicators_table = crime_df[["REF_DATE", "GEO", "DGUID", "Violations", "Statistics"]]
#crime_indicators_table.head()

# %%
food_df = pd.read_csv('../API/Resources/41100009-eng/41100009.csv')
food_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Aboriginal identity', 'Age group', 'Sex',
#        'Number of persons in the household', 'Food security', 'Statistics',
#        'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE',
#        'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
# Create a new table that takes the Aboriginal Identity data and all the columns relating to geo and food security
food_security_table = food_df[["REF_DATE", "GEO", "Sex", "Age group",
                                     "Aboriginal identity", "Food security", "Statistics", "VALUE"]]

# %%
food_df.columns
food_df.head()
# Out:
#    REF_DATE     GEO           DGUID         Aboriginal identity  \
# 0      2012  Canada  2016A000011124  Total, Aboriginal identity
# 1      2012  Canada  2016A000011124  Total, Aboriginal identity
# 2      2012  Canada  2016A000011124  Total, Aboriginal identity
# 3      2012  Canada  2016A000011124  Total, Aboriginal identity
# 4      2012  Canada  2016A000011124  Total, Aboriginal identity
#
#                  Age group         Sex  \
# 0  Total, 6 years and over  Both sexes
# 1  Total, 6 years and over  Both sexes
# 2  Total, 6 years and over  Both sexes
# 3  Total, 6 years and over  Both sexes
# 4  Total, 6 years and over  Both sexes
#
#           Number of persons in the household                   Food security  \
# 0  Total, number of persons in the household            Total, food security
# 1  Total, number of persons in the household            Total, food security
# 2  Total, number of persons in the household            Total, food security
# ...

# %%
# Create a new table that shows aboriginal identity and all the columns relating to food security
food_security_table = food_df[["REF_DATE", "GEO", "DGUID",
                               "Aboriginal identity", "Age group", "Sex",
                               "Food security", "Statistics", "VALUE"]]
food_security_table.head()
# Out:
#    REF_DATE     GEO           DGUID         Aboriginal identity  \
# 0      2012  Canada  2016A000011124  Total, Aboriginal identity
# 1      2012  Canada  2016A000011124  Total, Aboriginal identity
# 2      2012  Canada  2016A000011124  Total, Aboriginal identity
# 3      2012  Canada  2016A000011124  Total, Aboriginal identity
# 4      2012  Canada  2016A000011124  Total, Aboriginal identity
#
#                  Age group         Sex                   Food security  \
# 0  Total, 6 years and over  Both sexes            Total, food security
# 1  Total, 6 years and over  Both sexes            Total, food security
# 2  Total, 6 years and over  Both sexes            Total, food security
# 3  Total, 6 years and over  Both sexes            Total, food security
# 4  Total, 6 years and over  Both sexes  High or marginal food security
#
#                      Statistics     VALUE
# 0             Number of persons  963110.0
# 1                       Percent     100.0
# ...

# %%
food_security_table["Food security"].unique()
# Out:
# array(['Total, food security', 'High or marginal food security',
#        'Low food security', 'Very low food security',
#        'Food security not specified'], dtype=object)

# %%
food_security_table["GEO"].unique()
# Out:
# array(['Canada', 'Atlantic', 'Quebec', 'Ontario', 'Manitoba',
#        'Saskatchewan', 'Alberta', 'British Columbia', 'Yukon',
#        'Northwest Territories', 'Nunavut'], dtype=object)

# %%
#food_security_table.tail()

# Create a pivot table to isolate food security indicators between First Nations, Inuit, Métis, and Non-Aboriginal identities
food_security_df = food_security_table.loc[food_security_table["Statistics"] == 'Percent']
pivoted_df = food_security_df.pivot_table(index=["REF_DATE", "GEO", "Sex", "Aboriginal identity"], columns="Food security", values="VALUE").reset_index()
pivoted_df.head()
# Out:
# Food security  REF_DATE      GEO         Sex  \
# 0                  2012  Alberta  Both sexes
# 1                  2012  Alberta  Both sexes
# 2                  2012  Alberta  Both sexes
# 3                  2012  Alberta  Both sexes
# 4                  2012  Alberta  Both sexes
#
# Food security                                Aboriginal identity  \
# 0                          First Nations (North American Indian)
# 1              First Nations (North American Indian), Registe...
# 2              First Nations (North American Indian), not a R...
# 3                                                   Inuk (Inuit)
# 4                                                          Métis
#
# Food security  Food security not specified  High or marginal food security  \
# 0                                 6.380000                       73.617391
# 1                                 6.266667                       73.157895
# ...

# %%
pivoted_df
# Out:
# Food security  REF_DATE           GEO         Sex  \
# 0                  2012       Alberta  Both sexes
# 1                  2012       Alberta  Both sexes
# 2                  2012       Alberta  Both sexes
# 3                  2012       Alberta  Both sexes
# 4                  2012       Alberta  Both sexes
# 5                  2012       Alberta  Both sexes
# 6                  2012       Alberta      Female
# 7                  2012       Alberta      Female
# 8                  2012       Alberta      Female
# 9                  2012       Alberta      Female
# 10                 2012       Alberta      Female
# 11                 2012       Alberta      Female
# 12                 2012       Alberta        Male
# 13                 2012       Alberta        Male
# 14                 2012       Alberta        Male
# 15                 2012       Alberta        Male
# 16                 2012       Alberta        Male
# 17                 2012       Alberta        Male
# ...

# %%
loc_pivoted_df = pivoted_df.loc[pivoted_df["Aboriginal identity"] == 'Total, Aboriginal identity']
loc_pivoted_df
# Out:
# Food security  REF_DATE                    GEO         Sex  \
# 5                  2012                Alberta  Both sexes
# 11                 2012                Alberta      Female
# 17                 2012                Alberta        Male
# 23                 2012               Atlantic  Both sexes
# 29                 2012               Atlantic      Female
# 35                 2012               Atlantic        Male
# 41                 2012       British Columbia  Both sexes
# 47                 2012       British Columbia      Female
# 53                 2012       British Columbia        Male
# 59                 2012                 Canada  Both sexes
# 65                 2012                 Canada      Female
# 71                 2012                 Canada        Male
# 77                 2012               Manitoba  Both sexes
# 82                 2012               Manitoba      Female
# 87                 2012               Manitoba        Male
# ...

# %%
#new_pivoted_df = pivoted_df.pivot_table(index=["REF_DATE", "GEO"], columns="Aboriginal identity", values="Sex").reset_index()
#new_pivoted_df.head()

# %%
food_security_table["Aboriginal identity"].unique()
# Out:
# array(['Total, Aboriginal identity',
#        'First Nations (North American Indian)',
#        'First Nations (North American Indian), Registered or Treaty Indian',
#        'First Nations (North American Indian), not a Registered or Treaty Indian',
#        'Métis', 'Inuk (Inuit)'], dtype=object)

# %%
food_security_table["Age group"].unique()
# Out:
# array(['Total, 6 years and over', '6 to 14 years', '15 to 24 years',
#        '25 to 54 years', '55 years and over'], dtype=object)

# %%
food_security_table["Food security"].unique()
# Out:
# array(['Total, food security', 'High or marginal food security',
#        'Low food security', 'Very low food security',
#        'Food security not specified'], dtype=object)

# %%
#We only want -- data, so create a new table that takes the -- and all the columns relating to --
suicide_df = pd.read_csv('../API/Resources/41100011-eng/41100011.csv')
suicide_df.head()
# Out:
#    REF_DATE     GEO           DGUID          Aboriginal identity  \
# 0      2012  Canada  2016A000011124  Total , Aboriginal identity
# 1      2012  Canada  2016A000011124  Total , Aboriginal identity
# 2      2012  Canada  2016A000011124  Total , Aboriginal identity
# 3      2012  Canada  2016A000011124  Total , Aboriginal identity
# 4      2012  Canada  2016A000011124  Total , Aboriginal identity
#
#                   Age group         Sex  \
# 0  Total, 18 years and over  Both sexes
# 1  Total, 18 years and over  Both sexes
# 2  Total, 18 years and over  Both sexes
# 3  Total, 18 years and over  Both sexes
# 4  Total, 18 years and over  Both sexes
#
#     Perceived mental health and suicidal thoughts  \
# 0                  Total, perceived mental health
# 1                  Total, perceived mental health
# 2                  Total, perceived mental health
# 3                  Total, perceived mental health
# 4  Excellent or very good perceived mental health
#
# ...

# %%
suicide_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Aboriginal identity', 'Age group', 'Sex',
#        'Perceived mental health and suicidal thoughts', 'Statistics', 'UOM',
#        'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE',
#        'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
suicide_indicators_table = suicide_df[["REF_DATE", "GEO", "DGUID",
                               "Aboriginal identity", "Age group", "Sex",
                               "Perceived mental health and suicidal thoughts", "Statistics"]]
suicide_indicators_table.head()
# Out:
#    REF_DATE     GEO           DGUID          Aboriginal identity  \
# 0      2012  Canada  2016A000011124  Total , Aboriginal identity
# 1      2012  Canada  2016A000011124  Total , Aboriginal identity
# 2      2012  Canada  2016A000011124  Total , Aboriginal identity
# 3      2012  Canada  2016A000011124  Total , Aboriginal identity
# 4      2012  Canada  2016A000011124  Total , Aboriginal identity
#
#                   Age group         Sex  \
# 0  Total, 18 years and over  Both sexes
# 1  Total, 18 years and over  Both sexes
# 2  Total, 18 years and over  Both sexes
# 3  Total, 18 years and over  Both sexes
# 4  Total, 18 years and over  Both sexes
#
#     Perceived mental health and suicidal thoughts  \
# 0                  Total, perceived mental health
# 1                  Total, perceived mental health
# 2                  Total, perceived mental health
# 3                  Total, perceived mental health
# 4  Excellent or very good perceived mental health
#
# ...

# %%
suicide_indicators_table.tail()
# Out:
#        REF_DATE      GEO        DGUID Aboriginal identity          Age group  \
# 38011      2012  Nunavut  2016A000262        Inuk (Inuit)  55 years and over
# 38012      2012  Nunavut  2016A000262        Inuk (Inuit)  55 years and over
# 38013      2012  Nunavut  2016A000262        Inuk (Inuit)  55 years and over
# 38014      2012  Nunavut  2016A000262        Inuk (Inuit)  55 years and over
# 38015      2012  Nunavut  2016A000262        Inuk (Inuit)  55 years and over
#
#           Sex      Perceived mental health and suicidal thoughts  \
# 38011  Female      Never seriously considered committing suicide
# 38012  Female  Not specified, seriously considered committing...
# 38013  Female  Not specified, seriously considered committing...
# 38014  Female  Not specified, seriously considered committing...
# 38015  Female  Not specified, seriously considered committing...
#
#                          Statistics
# 38011  High 95% confidence interval
# 38012             Number of Persons
# ...

# %%
#merged_df = pd.merge(food_df, suicide_df, on='GEO', how='left')

# %%
#filter data to split up types
suicide_indicators_table["Aboriginal identity"].unique()
# Out:
# array(['Total , Aboriginal identity',
#        'First Nations (North American Indian)',
#        'First Nations (North American Indian), Registered or Treaty Indian',
#        'First Nations (North American Indian), not a Registered or Treaty Indian',
#        'Métis', 'Inuk (Inuit)'], dtype=object)

# %%
FN_suicide_df = suicide_df[suicide_df["Aboriginal identity"] == "First Nations (North American Indian)"]
FN_suicide_df
# Out:
#        REF_DATE      GEO           DGUID  \
# 576        2012   Canada  2016A000011124
# 577        2012   Canada  2016A000011124
# 578        2012   Canada  2016A000011124
# 579        2012   Canada  2016A000011124
# 580        2012   Canada  2016A000011124
# 581        2012   Canada  2016A000011124
# 582        2012   Canada  2016A000011124
# 583        2012   Canada  2016A000011124
# 584        2012   Canada  2016A000011124
# 585        2012   Canada  2016A000011124
# 586        2012   Canada  2016A000011124
# 587        2012   Canada  2016A000011124
# 588        2012   Canada  2016A000011124
# 589        2012   Canada  2016A000011124
# 590        2012   Canada  2016A000011124
# 591        2012   Canada  2016A000011124
# 592        2012   Canada  2016A000011124
# 593        2012   Canada  2016A000011124
# 594        2012   Canada  2016A000011124
# 595        2012   Canada  2016A000011124
# 596        2012   Canada  2016A000011124
# 597        2012   Canada  2016A000011124
# ...

# %%
FN_suicide_df["Statistics"].unique()
# Out:
# array(['Number of Persons', 'Percent', 'Low 95% confidence interval',
#        'High 95% confidence interval'], dtype=object)

# %%
FN_suicide = FN_suicide_df[FN_suicide_df["Statistics"] == "Low 95% confidence interval"]
FN_suicide
# Out:
#        REF_DATE      GEO           DGUID  \
# 578        2012   Canada  2016A000011124
# 582        2012   Canada  2016A000011124
# 586        2012   Canada  2016A000011124
# 590        2012   Canada  2016A000011124
# 594        2012   Canada  2016A000011124
# 598        2012   Canada  2016A000011124
# 602        2012   Canada  2016A000011124
# 606        2012   Canada  2016A000011124
# 610        2012   Canada  2016A000011124
# 614        2012   Canada  2016A000011124
# 618        2012   Canada  2016A000011124
# 622        2012   Canada  2016A000011124
# 626        2012   Canada  2016A000011124
# 630        2012   Canada  2016A000011124
# 634        2012   Canada  2016A000011124
# 638        2012   Canada  2016A000011124
# 642        2012   Canada  2016A000011124
# 646        2012   Canada  2016A000011124
# 650        2012   Canada  2016A000011124
# 654        2012   Canada  2016A000011124
# 658        2012   Canada  2016A000011124
# 662        2012   Canada  2016A000011124
# ...

# %%
#FN_avg_suicide = FN_suicide.groupby()

# %%
suicide_indicators_table["Age group"].unique()
# Out:
# array(['Total, 18 years and over', '18 to 24 years', '25 to 54 years',
#        '55 years and over'], dtype=object)

# %%
suicide_indicators_table["Perceived mental health and suicidal thoughts"].unique()
# Out:
# array(['Total, perceived mental health',
#        'Excellent or very good perceived mental health',
#        'Good perceived mental health',
#        'Fair or poor perceived mental health',
#        'Perceived mental health not specified',
#        'Total, suicidal thoughts',
#        'Ever seriously considered committing suicide',
#        'Seriously considered committing suicide in the past 12 months',
#        'Seriously considered committing suicide but not in the past 12 months',
#        'Not specified, seriously considered committing suicide in the past 12 months',
#        'Never seriously considered committing suicide',
#        'Not specified, seriously considered committing suicide'],
#       dtype=object)

# %%
suicide_indicators_table["Statistics"].unique()
# Out:
# array(['Number of Persons', 'Percent', 'Low 95% confidence interval',
#        'High 95% confidence interval'], dtype=object)

# %%
#df[df["column"] == "condition"]
#df[condition]

# %%
#merged_df = pd.merge(food_security_table, suicide_indicators_table, on='Age group', how='outer')

# %%
#merged_df.head()

# %%
#merged_df.tail()

# %%
merged_identity_df = pd.merge(food_security_table, suicide_indicators_table, on='Aboriginal identity', how='outer')

# %%
merged_identity_df.head()
# Out:
#    REF_DATE_x   GEO_x         DGUID_x         Aboriginal identity  \
# 0      2012.0  Canada  2016A000011124  Total, Aboriginal identity
# 1      2012.0  Canada  2016A000011124  Total, Aboriginal identity
# 2      2012.0  Canada  2016A000011124  Total, Aboriginal identity
# 3      2012.0  Canada  2016A000011124  Total, Aboriginal identity
# 4      2012.0  Canada  2016A000011124  Total, Aboriginal identity
#
#                Age group_x       Sex_x  \
# 0  Total, 6 years and over  Both sexes
# 1  Total, 6 years and over  Both sexes
# 2  Total, 6 years and over  Both sexes
# 3  Total, 6 years and over  Both sexes
# 4  Total, 6 years and over  Both sexes
#
#           Number of persons in the household                   Food security  \
# 0  Total, number of persons in the household            Total, food security
# 1  Total, number of persons in the household            Total, food security
# 2  Total, number of persons in the household            Total, food security
# ...

# %%
merged_identity_df.tail()
# Out:
#            REF_DATE_x GEO_x DGUID_x          Aboriginal identity Age group_x  \
# 627290131         NaN   NaN     NaN  Total , Aboriginal identity         NaN
# 627290132         NaN   NaN     NaN  Total , Aboriginal identity         NaN
# 627290133         NaN   NaN     NaN  Total , Aboriginal identity         NaN
# 627290134         NaN   NaN     NaN  Total , Aboriginal identity         NaN
# 627290135         NaN   NaN     NaN  Total , Aboriginal identity         NaN
#
#           Sex_x Number of persons in the household Food security Statistics_x  \
# 627290131   NaN                                NaN           NaN          NaN
# 627290132   NaN                                NaN           NaN          NaN
# 627290133   NaN                                NaN           NaN          NaN
# 627290134   NaN                                NaN           NaN          NaN
# 627290135   NaN                                NaN           NaN          NaN
#
# ...

# %%
merged_identity_df["Aboriginal identity"].unique()
# Out:
# array(['Total, Aboriginal identity',
#        'First Nations (North American Indian)',
#        'First Nations (North American Indian), Registered or Treaty Indian',
#        'First Nations (North American Indian), not a Registered or Treaty Indian',
#        'Métis', 'Inuk (Inuit)', 'Total , Aboriginal identity'],
#       dtype=object)

# %%
#aboriginal = merged_identity_df[merged_identity_df["Aboriginal identity"] == "Total , Aboriginal identity"]

# %%
merged_identity_df["Aboriginal identity"]
