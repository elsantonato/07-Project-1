# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

health_df = pd.read_csv("../Input/Health_13100458.csv")
health_df.head()
# Out:
#     REF_DATE     GEO  DGUID         Sex Aboriginal identity Indicators  \
# 0  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 1  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 2  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 3  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 4  2007/2010  Canada    NaN  Both sexes    Total population     Asthma
#
#                                      Characteristics   UOM  UOM_ID  \
# 0                              Age-standardized rate  Rate     257
# 1  Low 95% confidence interval, age-standardized ...  Rate     257
# 2  High 95% confidence interval, age-standardized...  Rate     257
# 3  Coefficient of variation for age-standardized ...  Rate     257
# 4                              Age-standardized rate  Rate     257
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE STATUS  SYMBOL  \
# 0        units           0  v65335813  1.1.1.1.1   12.1    NaN     NaN
# 1        units           0  v65335814  1.1.1.1.2   12.0    NaN     NaN
# 2        units           0  v65335815  1.1.1.1.3   12.3    NaN     NaN
# 3        units           0  v65335816  1.1.1.1.4    0.7    NaN     NaN
# 4        units           0  v65335833  1.1.1.2.1    8.7    NaN     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         1
# 1         NaN         1
# 2         NaN         1
# 3         NaN         1
# 4         NaN         1

# %%
# Create a new table that takes the Aboriginal Identity data and all the columns relating to geo and health
health_indicators_table = health_df[["GEO", "Sex", 
                                     "Aboriginal identity", "Indicators", "Characteristics", "VALUE"]]
health_indicators_table.head()
# Out:
#       GEO         Sex Aboriginal identity Indicators  \
# 0  Canada  Both sexes    Total population  Arthritis
# 1  Canada  Both sexes    Total population  Arthritis
# 2  Canada  Both sexes    Total population  Arthritis
# 3  Canada  Both sexes    Total population  Arthritis
# 4  Canada  Both sexes    Total population     Asthma
#
#                                      Characteristics  VALUE
# 0                              Age-standardized rate   12.1
# 1  Low 95% confidence interval, age-standardized ...   12.0
# 2  High 95% confidence interval, age-standardized...   12.3
# 3  Coefficient of variation for age-standardized ...    0.7
# 4                              Age-standardized rate    8.7

# %%
First_Nations_df = health_indicators_table.loc[health_indicators_table["Characteristics"] == 'Age-standardized rate']
First_Nations_df_sex = First_Nations_df.loc[health_indicators_table["Sex"] == 'Both sexes']
First_Nations_df_sex_drink = First_Nations_df_sex.loc[health_indicators_table["Indicators"] == "5 or more drinks on one occasion, at least once a month in the past year"]
First_Nations_df_sex_drink.head()
# Out:
#         GEO         Sex                 Aboriginal identity  \
# 68   Canada  Both sexes                    Total population
# 224  Canada  Both sexes                       First Nations
# 380  Canada  Both sexes                               Métis
# 536  Canada  Both sexes                               Inuit
# 692  Canada  Both sexes  Non-Aboriginal identity population
#
#                                             Indicators        Characteristics  \
# 68   5 or more drinks on one occasion, at least onc...  Age-standardized rate
# 224  5 or more drinks on one occasion, at least onc...  Age-standardized rate
# 380  5 or more drinks on one occasion, at least onc...  Age-standardized rate
# 536  5 or more drinks on one occasion, at least onc...  Age-standardized rate
# 692  5 or more drinks on one occasion, at least onc...  Age-standardized rate
#
#      VALUE
# 68    18.8
# 224   26.5
# 380   26.6
# 536   26.2
# 692   18.5

# %%
clean_drinking=First_Nations_df_sex_drink[["GEO", "Aboriginal identity", "VALUE"]]
pivoted = clean_drinking.pivot_table(index=["GEO"], columns="Aboriginal identity", values="VALUE").reset_index()
pivoted_clean_drinking=pivoted[["GEO", "First Nations", "Non-Aboriginal identity population"]]
pivoted_clean_drinking_droped=pivoted_clean_drinking.dropna(subset=["First Nations"])
pivoted_clean_drinking_droped
# Out:
# Aboriginal identity                        GEO  First Nations  \
# 0                                      Alberta           32.1
# 1                             British Columbia           23.3
# 2                                       Canada           26.5
# 3                                     Manitoba           27.4
# 4                                New Brunswick           24.7
# 5                    Newfoundland and Labrador           29.2
# 6                        Northwest Territories           35.9
# 7                                  Nova Scotia           19.4
# 9                                      Ontario           26.6
# 11                                      Quebec           21.3
# 12                                Saskatchewan           29.5
# 13                                       Yukon           38.1
#
# Aboriginal identity  Non-Aboriginal identity population
# 0                                                  19.9
# 1                                                  16.7
# 2                                                  18.5
# 3                                                  19.2
# 4                                                  21.7
# 5                                                  26.1
# 6                                                  28.2
# 7                                                  22.3
# 9                                                  17.2
# 11                                                 19.5
# 12                                                 21.2
# 13                                                 24.3

# %%
geo_list_FN=list(pivoted_clean_drinking_droped["GEO"])
geo_list_FN
# Out:
# ['Alberta',
#  'British Columbia',
#  'Canada',
#  'Manitoba',
#  'New Brunswick',
#  'Newfoundland and Labrador',
#  'Northwest Territories',
#  'Nova Scotia',
#  'Ontario',
#  'Quebec',
#  'Saskatchewan',
#  'Yukon']

# %%
colors=["b","r"]
drinking_chart=pivoted_clean_drinking_droped.plot(kind="bar", figsize=(15,8), color=colors)
x_axis = np.arange(len(geo_list_FN))
plt.xticks(x_axis,geo_list_FN, rotation=20)
plt.title("Percentage of Heavy Drinking: First Nations and Non-aboriginal population")
plt.ylabel ("Percentage")
plt.legend(loc='upper left')
fig_path="../Output/Percentage_drinking_all_provinces.png"
plt.savefig(fig_path)
plt.show()

# %%
geo_list=list(pivoted_clean_drinking["GEO"])
geo_list

# %%
drinking_Inuit=pivoted.dropna(subset=["Inuit"])
drinking_Inuit_clean=drinking_Inuit[["GEO", "First Nations","Inuit","Non-Aboriginal identity population"]]
drinking_Inuit_clean

# %%
geo_list2=list(drinking_Inuit_clean["GEO"])
geo_list2

# %%
colors2=["b","g","r"]
drinking_chart_Inuit=drinking_Inuit_clean.plot(kind="bar", figsize=(11.2,7), color=colors2)
x_axis = np.arange(len(geo_list2))
plt.xticks(x_axis,geo_list2, rotation=20)
plt.title("Percentage of Heavy Drinking:First Nations, Inuit and Non-aboriginal population")
plt.ylabel ("Percentage")
plt.legend(loc='upper left')
fig_path="../Output/Percentage_drinking_Inuit.png"
plt.savefig(fig_path)
plt.show()

# %%
drinking_Metis=pivoted.dropna(subset=["Métis"])
drinking_Metis
drinking_Metis_clean=drinking_Metis[["GEO", "First Nations","Métis","Non-Aboriginal identity population"]]
drinking_Metis_clean

# %%
geo_list3=list(drinking_Metis_clean["GEO"])
geo_list3

# %%
colors3=["b","c","r"]
drinking_chart_Metis=drinking_Metis_clean.plot(kind="bar", figsize=(15,8), color=colors3)
x_axis = np.arange(len(geo_list3))
plt.xticks(x_axis,geo_list3)
plt.title("Percentage of Heavy Drinking:First Nations, Métis and Non-aboriginal population")
plt.ylabel ("Percentage")
plt.legend(loc='upper left')
fig_path="../Output/Percentage_drinking_Metis.png"
plt.savefig(fig_path)
plt.show()
