# %%
import pandas as pd
import matplotlib.pyplot as plt

% matplotlib inline

health_df = pd.read_csv('../API/Resources/Health Indicators - 13100458-eng/13100458.csv')
#health_df.head()
health_df.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Sex', 'Aboriginal identity', 'Indicators',
#        'Characteristics', 'UOM', 'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID',
#        'VECTOR', 'COORDINATE', 'VALUE', 'STATUS', 'SYMBOL', 'TERMINATED',
#        'DECIMALS'],
#       dtype='object')

# %%
health_df.head()
# Out:
#     REF_DATE     GEO  DGUID         Sex Aboriginal identity Indicators  \
# 0  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 1  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 2  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 3  2007/2010  Canada    NaN  Both sexes    Total population  Arthritis
# 4  2007/2010  Canada    NaN  Both sexes    Total population     Asthma
#
#                                      Characteristics   UOM  UOM_ID  \
# 0                              Age-standardized rate  Rate     257
# 1  Low 95% confidence interval, age-standardized ...  Rate     257
# 2  High 95% confidence interval, age-standardized...  Rate     257
# 3  Coefficient of variation for age-standardized ...  Rate     257
# 4                              Age-standardized rate  Rate     257
#
#   SCALAR_FACTOR  SCALAR_ID     VECTOR COORDINATE  VALUE STATUS  SYMBOL  \
# 0        units           0  v65335813  1.1.1.1.1   12.1    NaN     NaN
# 1        units           0  v65335814  1.1.1.1.2   12.0    NaN     NaN
# 2        units           0  v65335815  1.1.1.1.3   12.3    NaN     NaN
# 3        units           0  v65335816  1.1.1.1.4    0.7    NaN     NaN
# 4        units           0  v65335833  1.1.1.2.1    8.7    NaN     NaN
#
#    TERMINATED  DECIMALS
# 0         NaN         1
# 1         NaN         1
# 2         NaN         1
# 3         NaN         1
# 4         NaN         1

# %%
# Create a new table that takes the Aboriginal Identity data and all the columns relating to geo and health
health_indicators_table = health_df[["REF_DATE", "GEO", "Sex", 
                                     "Aboriginal identity", "Indicators", "Characteristics", "VALUE"]]

# %%
health_indicators_table.head()

# Create a pivot table to isolate health indicators between First Nations, Inuit, Métis, and Non-Aboriginal identities
First_Nations_df = health_indicators_table.loc[health_indicators_table["Characteristics"] == 'Age-standardized rate']
pivoted_df = First_Nations_df.pivot_table(index=["REF_DATE",  "GEO", "Sex","Indicators"], columns="Aboriginal identity", values="VALUE").reset_index()
pivoted_df.head()
# Out:
# Aboriginal identity   REF_DATE      GEO         Sex  \
# 0                    2007/2010  Alberta  Both sexes
# 1                    2007/2010  Alberta  Both sexes
# 2                    2007/2010  Alberta  Both sexes
# 3                    2007/2010  Alberta  Both sexes
# 4                    2007/2010  Alberta  Both sexes
#
# Aboriginal identity                                         Indicators  \
# 0                    5 or more drinks on one occasion, at least onc...
# 1                                                            Arthritis
# 2                                                               Asthma
# 3                    Body mass index, self-reported, adult (18 year...
# 4                    Body mass index, self-reported, adult (18 year...
#
# Aboriginal identity  First Nations  Inuit  Métis  \
# 0                             32.1    NaN   31.9
# 1                             10.8    NaN   10.8
# 2                             15.7    NaN   11.1
# 3                             33.5    NaN   24.9
# 4                             16.9    NaN   27.5
#
# Aboriginal identity  Non-Aboriginal identity population  Total population
# 0                                                  19.9              20.6
# 1                                                  11.4              11.3
# 2                                                   9.1               9.3
# 3                                                  16.9              17.5
# 4                                                  32.8              32.4

# %%
pivoted_alcohol_df = pivoted_df[pivoted_df["Indicators"] == "5 or more drinks on one occasion, at least once a month in the past year"]
pivoted_alcohol_df.head()
# Out:
# Aboriginal identity   REF_DATE               GEO         Sex  \
# 0                    2007/2010           Alberta  Both sexes
# 39                   2007/2010           Alberta     Females
# 78                   2007/2010           Alberta       Males
# 115                  2007/2010  British Columbia  Both sexes
# 154                  2007/2010  British Columbia     Females
#
# Aboriginal identity                                         Indicators  \
# 0                    5 or more drinks on one occasion, at least onc...
# 39                   5 or more drinks on one occasion, at least onc...
# 78                   5 or more drinks on one occasion, at least onc...
# 115                  5 or more drinks on one occasion, at least onc...
# 154                  5 or more drinks on one occasion, at least onc...
#
# Aboriginal identity  First Nations  Inuit  Métis  \
# 0                             32.1    NaN   31.9
# 39                            27.4    NaN   22.6
# 78                            38.2    NaN   41.5
# 115                           23.3    NaN   23.4
# 154                           17.4    NaN   18.5
#
# Aboriginal identity  Non-Aboriginal identity population  Total population
# 0                                                  19.9              20.6
# 39                                                 12.2              12.9
# 78                                                 27.4              28.0
# 115                                                16.7              17.0
# 154                                                10.3              10.7

# %%
alcohol_FN = pivoted_alcohol_df.groupby("Indicators").count()["First Nations"]
alcohol_Inuit = pivoted_alcohol_df.groupby("Indicators").count()["Inuit"]
alcohol_Metis = pivoted_alcohol_df.groupby("Indicators").count()["Métis"]

plt.scatter(x = alcohol_FN, y, s, c, )
# Out:
# Indicators
# 5 or more drinks on one occasion, at least once a month in the past year    11
# Name: Inuit, dtype: int64

# %%
pivoted_alcohol_df.groupby("Indicators").max()
# Out:
# Aboriginal identity                                  REF_DATE    GEO    Sex  \
# Indicators
# 5 or more drinks on one occasion, at least once...  2007/2010  Yukon  Males
#
# Aboriginal identity                                 First Nations  Inuit  \
# Indicators
# 5 or more drinks on one occasion, at least once...           45.1   46.3
#
# Aboriginal identity                                 Métis  \
# Indicators
# 5 or more drinks on one occasion, at least once...   44.9
#
# Aboriginal identity                                 Non-Aboriginal identity population  \
# Indicators
# 5 or more drinks on one occasion, at least once...                                38.4
#
# Aboriginal identity                                 Total population
# Indicators
# 5 or more drinks on one occasion, at least once...              38.2

# %%
pivoted_alcohol_df.groupby("Indicators").min()
# Out:
# Aboriginal identity                                  REF_DATE      GEO  \
# Indicators
# 5 or more drinks on one occasion, at least once...  2007/2010  Alberta
#
# Aboriginal identity                                        Sex  First Nations  \
# Indicators
# 5 or more drinks on one occasion, at least once...  Both sexes           17.4
#
# Aboriginal identity                                 Inuit  Métis  \
# Indicators
# 5 or more drinks on one occasion, at least once...   13.4   18.2
#
# Aboriginal identity                                 Non-Aboriginal identity population  \
# Indicators
# 5 or more drinks on one occasion, at least once...                                10.0
#
# Aboriginal identity                                 Total population
# Indicators
# 5 or more drinks on one occasion, at least once...              10.2

# %%
pivoted_alcohol_df.groupby("Indicators").mean()
# Out:
# Aboriginal identity                                 First Nations      Inuit  \
# Indicators
# 5 or more drinks on one occasion, at least once...      28.371429  28.681818
#
# Aboriginal identity                                     Métis  \
# Indicators
# 5 or more drinks on one occasion, at least once...  28.003333
#
# Aboriginal identity                                 Non-Aboriginal identity population  \
# Indicators
# 5 or more drinks on one occasion, at least once...                           21.378571
#
# Aboriginal identity                                 Total population
# Indicators
# 5 or more drinks on one occasion, at least once...         21.754762

# %%
pivoted_alcohol_df.groupby("Indicators").count()
# Out:
# Aboriginal identity                                 REF_DATE  GEO  Sex  \
# Indicators
# 5 or more drinks on one occasion, at least once...        42   42   42
#
# Aboriginal identity                                 First Nations  Inuit  \
# Indicators
# 5 or more drinks on one occasion, at least once...             35     11
#
# Aboriginal identity                                 Métis  \
# Indicators
# 5 or more drinks on one occasion, at least once...     30
#
# Aboriginal identity                                 Non-Aboriginal identity population  \
# Indicators
# 5 or more drinks on one occasion, at least once...                                  42
#
# Aboriginal identity                                 Total population
# Indicators
# 5 or more drinks on one occasion, at least once...                42

# %%
health_indicators_table["Aboriginal identity"].unique()
# Out:
# array(['Total population', 'First Nations', 'Métis', 'Inuit',
#        'Non-Aboriginal identity population'], dtype=object)

# %%
health_indicators_table["GEO"].unique()
# Out:
# array(['Canada', 'Newfoundland and Labrador', 'Prince Edward Island',
#        'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba',
#        'Saskatchewan', 'Alberta', 'British Columbia', 'Yukon',
#        'Northwest Territories', 'Nunavut'], dtype=object)

# %%
health_indicators_table["Indicators"].unique()
# Out:
# array(['Arthritis', 'Asthma',
#        'Body mass index, self-reported, youth (12 to 17 years old), overweight or obese',
#        'Body mass index, self-reported, adult (18 years and over), overweight or obese',
#        'Body mass index, self-reported, adult (18 years and over), obese',
#        'Body mass index, self-reported, adult (18 years and over), overweight',
#        'Breastfeeding initiation',
#        'Exclusive breastfeeding, at least 6 months',
#        'Contact with a medical doctor in the past 12 months',
#        'Has a regular medical doctor',
#        'Current smoker, daily or occasional', 'Current smoker, daily',
#        'Diabetes', 'Exposure to second-hand smoke at home',
#        'Exposure to second-hand smoke in the past month, in vehicles and/or public places',
#        'Exposure to second-hand smoke in the past month, in vehicles',
#        'Exposure to second-hand smoke in the past month, in public places',
#        '5 or more drinks on one occasion, at least once a month in the past year',
#        'Never had alcoholic drinks in the past 12 months',
#        'Food Insecurity, moderate or severe',
#        'Fruit and vegetable consumption, 5 times or more per day',
#        'High blood pressure, heart disease or suffering from effects of stroke',
#        'High blood pressure',
#        'Influenza immunization, less than one year ago',
#        'Life satisfaction, satisfied or very satisfied', 'Mood disorder',
#        'One or more chronic conditions',
#        'Pain or discomfort by severity, moderate or severe',
#        'Pain or discomfort that prevents activities',
#        'Participation and activity limitation, sometimes or often',
#        'Perceived health, very good or excellent',
#        'Perceived health, fair or poor',
#        'Perceived mental health, very good or excellent',
#        'Perceived mental health, fair or poor',
#        'Perceived life stress, quite a lot (15 years and over)',
#        'Physical activity during leisure-time, moderately active or active',
#        'Physical activity during leisure-time, inactive',
#        'Respiratory problems',
#        'Sense of belonging to local community, somewhat strong or very strong'],
#       dtype=object)

# %%
health_indicators_table["Characteristics"].unique()
# Out:
# array(['Age-standardized rate',
#        'Low 95% confidence interval, age-standardized rate',
#        'High 95% confidence interval, age-standardized rate',
#        'Coefficient of variation for age-standardized rate'], dtype=object)

# %%
Health_First_Nations_df = pivoted_df.loc[pivoted_df["Indicators"] == 'Body mass index, self-reported, youth (12 to 17 years old), overweight or obese']
Health_First_Nations_df.head()
# Out:
# Aboriginal identity   REF_DATE               GEO         Sex  \
# 6                    2007/2010           Alberta  Both sexes
# 45                   2007/2010           Alberta     Females
# 84                   2007/2010           Alberta       Males
# 121                  2007/2010  British Columbia  Both sexes
# 160                  2007/2010  British Columbia     Females
#
# Aboriginal identity                                         Indicators  \
# 6                    Body mass index, self-reported, youth (12 to 1...
# 45                   Body mass index, self-reported, youth (12 to 1...
# 84                   Body mass index, self-reported, youth (12 to 1...
# 121                  Body mass index, self-reported, youth (12 to 1...
# 160                  Body mass index, self-reported, youth (12 to 1...
#
# Aboriginal identity  First Nations  Inuit  Métis  \
# 6                             33.5    NaN   22.5
# 45                             NaN    NaN    NaN
# 84                            43.5    NaN   39.5
# 121                           18.2    NaN   34.4
# 160                            NaN    NaN    NaN
#
# Aboriginal identity  Non-Aboriginal identity population  Total population
# 6                                                  19.2              19.8
# 45                                                 11.6              12.2
# 84                                                 26.2              27.1
# 121                                                16.2              16.9
# 160                                                11.7              12.5
