# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reference the file where the CSV is located
income_province_path = "../API/IncomePerProvince.csv"
income_reserve_path = "../API/IncomePerReserve.csv"

# Import the data into a Pandas DataFrame
income_province = pd.read_csv(income_province_path)
income_province.head()

income_reserve = pd.read_csv(income_reserve_path)
income_reserve.head()
# Out:
#                    Provinces  Number of Income Recipients  Total Income  \
# 0                    Alberta                      27675.0  6.837989e+08
# 1           British Columbia                      48430.0  1.606989e+09
# 2                   Manitoba                      35330.0  6.811989e+08
# 3              New Brunswick                       4845.0  1.139837e+08
# 4  Newfoundland and Labrador                       1840.0  6.702494e+07
#
#    Average Total Income
# 0          24708.182294
# 1          33181.676130
# 2          19281.033682
# 3          23526.053664
# 4          36426.597826

# %%
merged_df = pd.merge(income_province, income_reserve, on='Provinces', how='outer')
merged_df
# Out:
#                     Provinces  Number of Income Recipients_x  \
# 0                      Canada                     27489395.0
# 1   Newfoundland and Labrador                       422695.0
# 2        Prince Edward Island                       113455.0
# 3                 Nova Scotia                       744275.0
# 4               New Brunswick                       594650.0
# 5                      Quebec                      6417010.0
# 6                     Ontario                     10556925.0
# 7                    Manitoba                       953960.0
# 8                Saskatchewan                       822545.0
# 9                     Alberta                      3054555.0
# 10           British Columbia                      3727715.0
# 11                      Yukon                        27920.0
# 12      Northwest Territories                        31265.0
# 13                    Nunavut                        22435.0
#
# ...

# %%
#drop canada
new_merged_df = merged_df.drop(merged_df.index[[0]])
#new_merged_df
final_merged_df = new_merged_df.sort_values(['Provinces'], ascending=[True])
final_merged_df
# Out:
#                     Provinces  Number of Income Recipients_x  \
# 9                     Alberta                      3054555.0
# 10           British Columbia                      3727715.0
# 7                    Manitoba                       953960.0
# 4               New Brunswick                       594650.0
# 1   Newfoundland and Labrador                       422695.0
# 12      Northwest Territories                        31265.0
# 3                 Nova Scotia                       744275.0
# 13                    Nunavut                        22435.0
# 6                     Ontario                     10556925.0
# 2        Prince Edward Island                       113455.0
# 5                      Quebec                      6417010.0
# 8                Saskatchewan                       822545.0
# 11                      Yukon                        27920.0
#
#     Average Total Income_x  Number of Income Recipients_y  Total Income  \
# ...

# %%
merged_rename = final_merged_df.rename(columns={'Average Total Income_x': 'Average Total Income(Province)',
                                         'Average Total Income_y': 'Average Total Income(Reserve)'})
merged_rename
# Out:
#                     Provinces  Number of Income Recipients_x  \
# 9                     Alberta                      3054555.0
# 10           British Columbia                      3727715.0
# 7                    Manitoba                       953960.0
# 4               New Brunswick                       594650.0
# 1   Newfoundland and Labrador                       422695.0
# 12      Northwest Territories                        31265.0
# 3                 Nova Scotia                       744275.0
# 13                    Nunavut                        22435.0
# 6                     Ontario                     10556925.0
# 2        Prince Edward Island                       113455.0
# 5                      Quebec                      6417010.0
# 8                Saskatchewan                       822545.0
# 11                      Yukon                        27920.0
#
#     Average Total Income(Province)  Number of Income Recipients_y  \
# ...

# %%
#merged_rename["Average Total Income(Province)"].unique()
#merged_rename["Average Total Income(Reserve)"].unique()
merged_rename["Provinces"].unique()
# Out:
# array(['Alberta', 'British Columbia', 'Manitoba', 'New Brunswick',
#        'Newfoundland and Labrador', 'Northwest Territories',
#        'Nova Scotia', 'Nunavut', 'Ontario', 'Prince Edward Island',
#        'Quebec', 'Saskatchewan', 'Yukon'], dtype=object)

# %%
N = 14
#p = province
p_income = (12778., 45616., 43767., 39141., 45210., 64586., 41479., 50689.,
       47915., 38899., 42546., 49409., 53809.)


fig, ax = plt.subplots()

ind = np.arange(N)    # the x locations for the groups
width = 0.35         # the width of the bars
p1 = ax.bar(ind, p_income, width, color='r')

#r=reserve

r_income = (24708.18229449, 33181.6761305 , 19281.03368242, 23526.05366357,
       36426.59782609, 31941. , 20698.14906832, 0,
       24568.00844695, 32564. , 26793.44109672, 20348.63305841,0)

p2 = ax.bar(ind + width, r_income, width, color='y')

ax.set_title('Average Income')
ax.set_xticks(ind + width / 2)
ax.set_xticklabels(('Alberta', 'British Columbia', 'Manitoba', 'New Brunswick',
       'Newfoundland and Labrador', 'Northwest Territories',
       'Nova Scotia', 'Nunavut', 'Ontario', 'Prince Edward Island',
       'Quebec', 'Saskatchewan', 'Yukon'))

ax.legend((p1[0], p2[0]), ('Men', 'Women'))
ax.yaxis.set_units(inch)
ax.autoscale_view()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-98936e28d6c9> in <module>()
#       9 ind = np.arange(N)    # the x locations for the groups
#      10 width = 0.35         # the width of the bars
# ---> 11 p1 = ax.bar(ind, p_income, width, color='r')
#      12
#      13 #r=reserve
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1853                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1854                         RuntimeWarning, stacklevel=2)
# -> 1855             return func(ax, *args, **kwargs)
#    1856
#    1857         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /anaconda3/lib/python3.6/site-packages/matplotlib/axes/_axes.py in bar(self, *args, **kwargs)
#    2231         x, height, width, y, linewidth = np.broadcast_arrays(
# ...

# %%
#income_reserve_rename["Average Total Income(Reserve)"].unique()
income_reserve_rename["Provinces"].unique()
# Out:
# array(['Alberta', 'British Columbia', 'Manitoba', 'New Brunswick',
#        'Newfoundland and Labrador', 'Northwest Territories',
#        'Nova Scotia', 'Ontario', 'Prince Edward Island', 'Quebec',
#        'Saskatchewan'], dtype=object)

# %%
data = [[45210., 38899., 41479., 39141., 42546., 47915., 43767.,
       49409., 62778., 45616., 53809., 64586., 50689.],
  [24708.18229449, 33181.6761305 , 19281.03368242, 23526.05366357,
       36426.59782609, 31941.        , 20698.14906832, 24568.00844695,
       32564.        , 26793.44109672, 20348.63305841]]
#p=province / r = reserve
ax = plt.subplot(111)
pX = ['Newfoundland and Labrador', 'Prince Edward Island',
       'Nova Scotia', 'New Brunswick', 'Quebec', 'Ontario', 'Manitoba',
       'Saskatchewan', 'Alberta', 'British Columbia', 'Yukon',
       'Northwest Territories', 'Nunavut']
rX = ['Alberta', 'British Columbia', 'Manitoba', 'New Brunswick',
       'Newfoundland and Labrador', 'Northwest Territories',
       'Nova Scotia', 'Ontario', 'Prince Edward Island', 'Quebec',
       'Saskatchewan']


ax.bar(pX, data[0], color = 'b', width = 0.25)
ax.bar(rX+0.25, data[1], color = 'g', width = 0.25)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a1cd27a25c6e> in <module>()
#      17
#      18 ax.bar(pX, data[0], color = 'b', width = 0.25)
# ---> 19 ax.bar(rX+0.25, data[1], color = 'g', width = 0.25)
#      20
#      21
#
# TypeError: can only concatenate list (not "float") to list
