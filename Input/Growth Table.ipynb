# %%
import numpy as np
import matplotlib.pyplot as plt
import math
import pandas as pd
import csv

pr_csv = "../API/Population Growth Per Province.csv"
pr = pd.read_csv(pr_csv)
pr = pr.drop(0)
pr = pr.set_index('Provinces')
pr = pr [['Population, 2016','Population, 2011', 'Growth Rate' ]]
pr = pr.rename(columns = {'Population, 2016':'Population per Province, 2016','Population, 2011':'Population Per Province, 2011','Growth Rate':'Province Growth Rate'})
re_csv = "../API/Population Growth Per Reserve.csv"
re = pd.read_csv(re_csv)
re = re.set_index('Provinces')
re = re[['Population, 2016','Population, 2011', 'Growth Rate' ]]
re = re.rename(columns = {'Population, 2016':'Population per Reserve, 2016','Population, 2011':'Population Per Reserve, 2011','Growth Rate':'Reserve Growth Rate'})
growth = pd.merge(pr,re, on='Provinces')
growth['Province Growth Rate'] = pd.Series(["{0:.2f}%".format(val) for val in growth['Province Growth Rate']], index = growth.index)
growth['Reserve Growth Rate'] = pd.Series([("{0:.2f}%".format(val)) for val in growth['Reserve Growth Rate']], index = growth.index)
growth
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-44-d99f17293ccc> in <module>()
#      18 growth = pd.merge(pr,re, on='Provinces')
#      19 growth['Province Growth Rate'] = pd.Series(["{0:.2f}%".format(val) for val in growth['Province Growth Rate']], index = growth.index)
# ---> 20 growth['Reserve Growth Rate'] = pd.Series([float("{0:.2f}%".format(val)) for val in growth['Reserve Growth Rate']], index = growth.index)
#      21 growth
#
# <ipython-input-44-d99f17293ccc> in <listcomp>(.0)
#      18 growth = pd.merge(pr,re, on='Provinces')
#      19 growth['Province Growth Rate'] = pd.Series(["{0:.2f}%".format(val) for val in growth['Province Growth Rate']], index = growth.index)
# ---> 20 growth['Reserve Growth Rate'] = pd.Series([float("{0:.2f}%".format(val)) for val in growth['Reserve Growth Rate']], index = growth.index)
#      21 growth
#
# ValueError: could not convert string to float: '-7.90%'

# %%
growth = growth.sort_values(by=['Provinces'])
g = growth['Reserve Growth Rate'].plot(kind='bar')
#[plt.text(v, i, '{:.2f}%'.format(v),va='center') for i, v in enumerate(growth['Reserve Growth Rate'])]
plt.title('Reserve Population Growth Rate')
plt.xlabel('Provinces')
plt.ylabel('Growth Rate')   
plt.savefig("../Output/Reserve Population Growth Rate.png")
plt.show
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-0d3201a75db6> in <module>()
#       1 growth = growth.sort_values(by=['Provinces'])
# ----> 2 g = growth['Reserve Growth Rate'].plot(kind='bar')
#       3 #[plt.text(v, i, '{:.2f}%'.format(v),va='center') for i, v in enumerate(growth['Reserve Growth Rate'])]
#       4 plt.title('Reserve Population Growth Rate')
#       5 plt.xlabel('Provinces')
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2739                            colormap=colormap, table=table, yerr=yerr,
#    2740                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2741                            **kwds)
#    2742     __call__.__doc__ = plot_series.__doc__
#    2743
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2000                  yerr=yerr, xerr=xerr,
#    2001                  label=label, secondary_y=secondary_y,
# -> 2002                  **kwds)
#    2003
#    2004
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1802         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1803
# -> 1804     plot_obj.generate()
#    1805     plot_obj.draw()
#    1806     return plot_obj.result
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     256     def generate(self):
#     257         self._args_adjust()
# --> 258         self._compute_plot_data()
#     259         self._setup_subplots()
#     260         self._make_plot()
#
# ~\Anaconda3\lib\site-packages\pandas\plotting\_core.py in _compute_plot_data(self)
#     371         if is_empty:
#     372             raise TypeError('Empty {0!r}: no numeric data to '
# --> 373                             'plot'.format(numeric_data.__class__.__name__))
#     374
#     375         self.data = numeric_data
#
# TypeError: Empty 'DataFrame': no numeric data to plot

# %%
g = growth['Province Growth Rate'].plot(kind='bar')
#[plt.text(v, i, '{:.2f}%'.format(v),va='center') for i, v in enumerate(growth['Reserve Growth Rate'])]
plt.title('Province Population Growth Rate')
plt.xlabel('Provinces')
plt.ylabel('Growth Rate')   
plt.savefig("../Output/Province Population Growth Rate.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
