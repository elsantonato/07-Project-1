# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reference the file where the CSV is located
suicidal_thoughts_path = "../API/suicidal_thoughts.csv"


# Import the data into a Pandas DataFrame
suicidal_thoughts = pd.read_csv(suicidal_thoughts_path)
suicidal_thoughts.head(2)
# Out:
#    REF_DATE     GEO           DGUID          Aboriginal identity  \
# 0      2012  Canada  2016A000011124  Total , Aboriginal identity
# 1      2012  Canada  2016A000011124  Total , Aboriginal identity
#
#                   Age group         Sex  \
# 0  Total, 18 years and over  Both sexes
# 1  Total, 18 years and over  Both sexes
#
#   Perceived mental health and suicidal thoughts         Statistics      UOM  \
# 0                Total, perceived mental health  Number of Persons  Persons
# 1                Total, perceived mental health            Percent  Percent
#
#    UOM_ID SCALAR_FACTOR  SCALAR_ID     VECTOR   COORDINATE     VALUE STATUS  \
# 0     249        units           0  v95715898  1.1.1.1.1.1  684880.0    NaN
# 1     239        units           0  v95715899  1.1.1.1.1.2     100.0    NaN
#
#    SYMBOL  TERMINATED  DECIMALS
# 0     NaN         NaN         0
# 1     NaN         NaN         1

# %%
suicidal_thoughts.columns
# Out:
# Index(['REF_DATE', 'GEO', 'DGUID', 'Aboriginal identity', 'Age group', 'Sex',
#        'Perceived mental health and suicidal thoughts', 'Statistics', 'UOM',
#        'UOM_ID', 'SCALAR_FACTOR', 'SCALAR_ID', 'VECTOR', 'COORDINATE', 'VALUE',
#        'STATUS', 'SYMBOL', 'TERMINATED', 'DECIMALS'],
#       dtype='object')

# %%
# Create a new table that takes the Aboriginal Identity data and all the columns relating to geo and mental/suicidal thoughts
suicidal_indicators = suicidal_thoughts[["REF_DATE", "GEO", "Aboriginal identity",  
                                     'Sex', 'Perceived mental health and suicidal thoughts',
                                    "VALUE"]]
suicidal_indicators.head()
# Out:
#    REF_DATE     GEO          Aboriginal identity         Sex  \
# 0      2012  Canada  Total , Aboriginal identity  Both sexes
# 1      2012  Canada  Total , Aboriginal identity  Both sexes
# 2      2012  Canada  Total , Aboriginal identity  Both sexes
# 3      2012  Canada  Total , Aboriginal identity  Both sexes
# 4      2012  Canada  Total , Aboriginal identity  Both sexes
#
#     Perceived mental health and suicidal thoughts     VALUE
# 0                  Total, perceived mental health  684880.0
# 1                  Total, perceived mental health     100.0
# 2                  Total, perceived mental health     100.0
# 3                  Total, perceived mental health     100.0
# 4  Excellent or very good perceived mental health  400170.0

# %%
suicidal_indicators["Perceived mental health and suicidal thoughts"].unique()
# Out:
# array(['Total, perceived mental health',
#        'Excellent or very good perceived mental health',
#        'Good perceived mental health',
#        'Fair or poor perceived mental health',
#        'Perceived mental health not specified',
#        'Total, suicidal thoughts',
#        'Ever seriously considered committing suicide',
#        'Seriously considered committing suicide in the past 12 months',
#        'Seriously considered committing suicide but not in the past 12 months',
#        'Not specified, seriously considered committing suicide in the past 12 months',
#        'Never seriously considered committing suicide',
#        'Not specified, seriously considered committing suicide'],
#       dtype=object)

# %%
# Create a pivot table to isolate suicidal indicators between First Nations, Inuit, Métis
First_Nations_df = suicidal_indicators.loc[suicidal_indicators["Perceived mental health and suicidal thoughts"] 
                                           == 'Excellent or very good perceived mental health']
pivoted_df = First_Nations_df.pivot_table(index=["REF_DATE",  "GEO", "Sex"], 
                                          columns="Aboriginal identity", values="VALUE").reset_index()
pivoted_df.head()
# Out:
# Aboriginal identity  REF_DATE       GEO         Sex  \
# 0                        2012   Alberta  Both sexes
# 1                        2012   Alberta      Female
# 2                        2012   Alberta        Male
# 3                        2012  Atlantic  Both sexes
# 4                        2012  Atlantic      Female
#
# Aboriginal identity  First Nations (North American Indian)  \
# 0                                               3020.33125
# 1                                               1660.66875
# 2                                               1403.13125
# 3                                               2186.98125
# 4                                               1255.23750
#
# Aboriginal identity  First Nations (North American Indian), Registered or Treaty Indian  \
# 0                                                           2219.09375
# 1                                                           1243.58750
# 2                                                           1281.52500
# 3                                                           1113.17500
# 4                                                            698.75625
#
# Aboriginal identity  First Nations (North American Indian), not a Registered or Treaty Indian  \
# 0                                                          1009.633333
# 1                                                           698.962500
# 2                                                           536.050000
# 3                                                          1119.243750
# 4                                                           599.981250
#
# Aboriginal identity  Inuk (Inuit)       Métis  Total , Aboriginal identity
# 0                      192.900000  4811.15625                   7827.48125
# 1                       94.087500  2618.95000                   4247.08125
# 2                             NaN  2238.39375                   3625.21875
# 3                      599.516667  1418.98750                   3921.36250
# 4                      269.883333   775.51250                   2178.41250

# %%
#Collect only data related to Aboriginal identity, First Nations
First_Nations_df = health_indicators_table.loc[health_indicators_table["Aboriginal identity"] == 'First Nations']
First_Nations_df.head()

# Isolate data related to age-standardized rate
#First_Nations_df = First_Nations_df.loc[First_Nations_df["Characteristics"] == 'Age-standardized rate']
#First_Nations_df.head()

# Pivot table to switch index coordinates 
#First_Nations_df.pivot_table(index=["REF_DATE",  "GEO", "Sex","Indicators"], columns="Aboriginal identity", values="VALUE").reset_index()

# %%
# Collect only data related to Aboriginal identity, Métis
#Métis_df = health_indicators_table.loc[health_indicators_table["Aboriginal identity"] == 'Métis']
#Métis_df.head()

# Isolate data related to age-standardized rate
#Métis_df = Métis_df.loc[Métis_df["Characteristics"] == 'Age-standardized rate']
#Métis_df.head()

# %%
new_suicidal_df = suicidal_thoughts[['GEO', 'Aboriginal identity','Age group',
                                     'Sex','Perceived mental health and suicidal thoughts']]
new_suicidal_df.head()
# Out:
#       GEO          Aboriginal identity                 Age group         Sex  \
# 0  Canada  Total , Aboriginal identity  Total, 18 years and over  Both sexes
# 1  Canada  Total , Aboriginal identity  Total, 18 years and over  Both sexes
# 2  Canada  Total , Aboriginal identity  Total, 18 years and over  Both sexes
# 3  Canada  Total , Aboriginal identity  Total, 18 years and over  Both sexes
# 4  Canada  Total , Aboriginal identity  Total, 18 years and over  Both sexes
#
#     Perceived mental health and suicidal thoughts
# 0                  Total, perceived mental health
# 1                  Total, perceived mental health
# 2                  Total, perceived mental health
# 3                  Total, perceived mental health
# 4  Excellent or very good perceived mental health

# %%
#new_suicidal_df["GEO"].unique()
#new_suicidal_df["Aboriginal identity"].unique()
#new_suicidal_df["Age group"].unique()
#new_suicidal_df["Sex"].unique()
#new_suicidal_df["Perceived mental health and suicidal thoughts"].unique()
#new_suicidal_df["Statistics"].unique()
# Out:
# array(['Total, perceived mental health',
#        'Excellent or very good perceived mental health',
#        'Good perceived mental health',
#        'Fair or poor perceived mental health',
#        'Perceived mental health not specified',
#        'Total, suicidal thoughts',
#        'Ever seriously considered committing suicide',
#        'Seriously considered committing suicide in the past 12 months',
#        'Seriously considered committing suicide but not in the past 12 months',
#        'Not specified, seriously considered committing suicide in the past 12 months',
#        'Never seriously considered committing suicide',
#        'Not specified, seriously considered committing suicide'],
#       dtype=object)

# %%
#new_suicidal_df['GEO'].value_counts()
#new_suicidal_df['Aboriginal identity'].value_counts()
#new_suicidal_df['Age group'].value_counts()
#new_suicidal_df['Sex'].value_counts()
#new_suicidal_df['Perceived mental health and suicidal thoughts'].value_counts()
