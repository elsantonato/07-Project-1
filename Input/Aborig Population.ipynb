# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reference the file where the CSV is located
population_csv_path = "../API/Male Population Age Breakdown Per Province.csv"

# Import the data into a Pandas DataFrame
aborig_population = pd.read_csv(population_csv_path)
aborig_population
# Out:
#                     Provinces     Total  Aboriginal  Non-aboriginal  \
# 0                      Canada  34460065     1673785        32786280
# 1   Newfoundland and Labrador    512255       45730          466525
# 2        Prince Edward Island    139685        2735          136945
# 3                 Nova Scotia    908340       51495          856850
# 4               New Brunswick    730710       29385          701325
# 5                      Quebec   7965450      182885         7782560
# 6                     Ontario  13242160      374395        12867765
# 7                    Manitoba   1240700      223310         1017385
# 8                Saskatchewan   1070555      175020          895535
# 9                     Alberta   3978145      258640         3719505
# 10           British Columbia   4560240      270585         4289655
# 11                      Yukon     35115        8195           26915
# 12      Northwest Territories     41135       20860           20275
# ...

# %%
A = [8.9, 2, 5.7, 4.0, 2.3, 2.8, 18, 16.3, 6.5, 5.9, 23.3, 50.7, 85.9]
B = [91.1, 98, 94.3, 96, 97.7, 97.2, 82, 83.7, 93.5, 94.1, 76.6, 49.3, 14.1]

province=['Newfoundland and Labrador', 'Prince Edward Island', 'Nova Scotia', 'New Brunswick', 
                 'Quebec', 'Ontario', 'Manitoba', 'Saskatchewan', 
                 'Alberta', 'British Columbia', 'Yukon', 'Northwest Territories', 'Nunavut']
Class=['Aboriginal','Non-aboriginal']
pos = np.arange(len(province))
aboriginal=[8.9, 2, 5.7, 4.0, 2.3, 2.8, 18, 16.3, 6.5, 5.9, 23.3, 50.7, 85.9]
non_aboriginal=[91.1, 98, 94.3, 96, 97.7, 97.2, 82, 83.7, 93.5, 94.1, 76.6, 49.3, 14.1]

fig, ax = plt.subplots(figsize=(12,12))
plt.bar(pos,aboriginal,color='green',edgecolor='black')
plt.bar(pos,non_aboriginal,color='red',edgecolor='black',bottom=aboriginal)
plt.xticks(pos, province, rotation=90, fontsize=10)
plt.xlabel('Province', fontsize=16)
plt.ylabel('Population(Percentage)', fontsize=16)
plt.title('Aborignal Population Per Province',fontsize=18)
plt.legend(Class,loc='best', )

plt.savefig("Aboriginal_Population.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
