# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# Reference the file where the CSV is located
population_csv_path = "../API/aborig_population.xls"

# Import the data into a Pandas DataFrame
aborig_population = pd.read_csv(population_csv_path, encoding='utf-8')
aborig_population
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-12-284bcc5c63c3> in <module>()
#       3
#       4 # Import the data into a Pandas DataFrame
# ----> 5 aborig_population = pd.read_csv(population_csv_path, encoding='utf-8')
#       6 aborig_population
#
# ...

# %%
# set width of bar

barWidth = 0.30

# set height of bar
province = [12778., 45616., 43767., 39141., 45210., 64586., 41479., 50689.,
47915., 38899., 42546., 49409., 53809.]

reserve = [24708.18229449, 33181.6761305 , 19281.03368242, 23526.05366357,
       36426.59782609, 31941. , 20698.14906832, 0,
       24568.00844695, 32564. , 26793.44109672, 20348.63305841,0]

 # Set position of bar on X axis
r1 = np.arange(len(province))
r2 = [x + barWidth for x in r1]


# Make the plot
plt.figure(figsize=(20, 10))  # width:20, height:3
ax1=plt.bar(r1, province, color='r', width=barWidth, edgecolor='white', label='Province', align='center')
ax2=plt.bar(r2, reserve, color='b', width=barWidth, edgecolor='white', label='Reserve',align='center')

# Add xticks on the middle of the group bars

plt.tick_params(labelsize=20)
plt.ylabel('Average Income', fontweight='bold',fontsize=18)
plt.xlabel('Province', fontweight='bold',fontsize=18)
plt.xticks([r + barWidth for r in range(len(province))], ['Alberta', 'British Columbia', 'Manitoba', 'New Brunswick',
                             'Newfoundland and Labrador', 'Northwest Territories',
                            'Nova Scotia', 'Nunavut', 'Ontario', 'Prince Edward Island',
                     'Quebec', 'Saskatchewan', 'Yukon'], rotation = 70,fontweight='bold', fontsize=18)

plt.legend(loc='best', prop={'size': 25})
plt.show()
#fig.savefig('../API/"Aboriginal_Population.png", bbox_inches='tight')

# %%
A = [8.9, 2, 5.7, 4.0, 2.3, 2.8, 18, 16.3, 6.5, 5.9, 23.3, 50.7, 85.9]
B = [91.1, 98, 94.3, 96, 97.7, 97.2, 82, 83.7, 93.5, 94.1, 76.6, 49.3, 14.1]

province=['NL', 'PE', 'NS', 'NB', 
                 'QC', 'ON', 'MB', 'SK', 
                 'AB', 'BC', 'YK', 'NT', 'NU']
Class=['Aboriginal','Non-aboriginal']
pos = np.arange(len(province))
aboriginal=[8.9, 2, 5.7, 4.0, 2.3, 2.8, 18, 16.3, 6.5, 5.9, 23.3, 50.7, 85.9]
non_aboriginal=[91.1, 98, 94.3, 96, 97.7, 97.2, 82, 83.7, 93.5, 94.1, 76.6, 49.3, 14.1]

fig, ax = plt.subplots(figsize=(40,20))# width:20, height:3
ax1 = plt.bar(pos,aboriginal,color='black',edgecolor='black')
ax2 = plt.bar(pos,non_aboriginal,color='yellow',edgecolor='black',bottom=aboriginal)
plt.tick_params(labelsize=35)
plt.xticks(pos, province, rotation=0, fontsize=35,fontweight='bold')
plt.xlabel('Province', fontsize=40,fontweight='bold')
plt.ylabel('Population(Percentage)', fontsize=40,fontweight='bold')
plt.title('Population Per Province',fontsize=45,fontweight='bold')
plt.legend(Class,loc=2, prop={'size': 45} )

for r1, r2 in zip(ax1, ax2):

    h1 = r1.get_height()
    h2 = r2.get_height()
    plt.text(r1.get_x() + r1.get_width() / 2., h1 / 2., "%d" % h1, ha="center", va="center", color="red", fontsize=30, fontweight="bold")
    plt.text(r2.get_x() + r2.get_width() / 2., h1 + h2 / 2., "%d" % h2, ha="center", va="center", color="red", fontsize=30, fontweight="bold")

plt.savefig('../Output/Population_Per_Province.jpeg', bbox_inches='tight')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# set width of bar

barWidth = 0.30

# set height of bar
non_aboriginal = [12778., 45616., 43767., 39141., 45210., 64586., 41479., 50689.,
                  47915., 38899., 42546., 49409., 53809.]
 
bboriginal = [24708.18229449, 33181.6761305 , 19281.03368242, 23526.05366357,
       36426.59782609, 31941. , 20698.14906832, 0,
       24568.00844695, 32564. , 26793.44109672, 20348.63305841,0]

 # Set position of bar on X axis
r1 = np.arange(len(province))
r2 = [x + barWidth for x in r1]


# Make the plot
plt.figure(figsize=(20, 10))  # width:20, height:3
ax1=plt.bar(r1, province, color='b', width=barWidth, edgecolor='white', label='Non-Aboriginal', align='center')
ax2=plt.bar(r2, reserve, color='y', width=barWidth, edgecolor='white', label='Aboriginal',align='center')

# Add xticks on the middle of the group bars

plt.tick_params(labelsize=20)
plt.ylabel('Average Income', fontweight='bold',fontsize=18)
plt.xlabel('Province', fontweight='bold',fontsize=18)
plt.xticks([r + barWidth for r in range(len(province))], ['AB', 'BC', 'MB', 'NB',
                             'NL', 'NT','NS', 'NU', 'ON', 'PE',
                             'QC', 'SK', 'YT'], rotation = 0,fontweight='bold', fontsize=18)

plt.legend(loc='best', prop={'size': 25})
plt.show()
#fig.savefig('../API/"Aboriginal_Population.png", bbox_inches='tight')
